# %%
import importlib
importlib.reload(seqanal)
import seqanal
importlib.reload(seqanal)
from seqanal import mySubj

# %%
subj = mySubj('./ssh__subj100/ssh__.dat')
subj.calculate_rt_mt()
subj.calculate_error_proportion()
subj.visualize_rt_mt()
subj.calculate_ipi()
subj.visualize_ipi()
# Out:
# Data loaded successfully.

# %%
subj.calculate_rt_mt()
subj.calculate_error_proportion()

# %%
subj.error_proportion
# Out:
#     seqType  Horizon  TotalCount  ErrorCount  ErrorRate
# 0         1        1          14           4   0.285714
# 1         1        2          12           1   0.083333
# 2         1        3          14           4   0.285714
# 3         1        4          12           5   0.416667
# 4         1        5          13           6   0.461538
# 5         1        6          16           7   0.437500
# 6         1        7          13           2   0.153846
# 7         1        8          14           5   0.357143
# 8         2        1          15           3   0.200000
# 9         2        3          14           2   0.142857
# 10        2        4          12           1   0.083333
# 11        2        5          14           5   0.357143
# 12        2        7          13           1   0.076923
# 13        2        8          14           4   0.285714
