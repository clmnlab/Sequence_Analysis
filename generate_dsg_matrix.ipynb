# %%
import pandas as pd

# %%
work_dir = '/Volumes/Diedrichsen_data$/data/SeqSpatialSupp_fMRI/behavioral_data/'
# import tsv file
pd.read_csv(work_dir + 'ssh__S01.dat',delimiter='\t')
# Out:
#     BN  TN  seqType  Horizon  PrepTime   startTime  startTimeReal
# 1    1   1        5     1000    8030.0    8030.013              9  \
# 1    2   1        5     1000   13030.0   13030.012             14
# 1    3   0        5     1000   18030.0   18030.027             19
# 1    4   0        5     1000   23030.0   23030.014             24
# 1    5   1        5     1000   28030.0   28030.000             29
# ..  ..  ..      ...      ...       ...         ...            ...
# 8   64   1        5     1000  368030.0  368031.961            368
# 8   65   0        5     1000  373030.0  373031.951            373
# 8   66   1        5     1000  378030.0  378031.951            378
# 8   67   0        5     1000  383030.0  383031.964            383
# 8   68   1        5     1000  388030.0  388031.959            388
#
#     startTRReal  startTRtime  press0  ...  pressTime4  timeThreshold
# 1        25.996            3       5  ...      6000.0         5000.0  \
# ...

# %%
# read npz file, smp1_100.npz

# %%
# Construct a design matrix for SPM
